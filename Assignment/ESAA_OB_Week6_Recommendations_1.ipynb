# %% [markdown]
# ## **1. 추천 시스템의 개요와 배경**

# %% [markdown]
# ### **추천 시스템의 개요**

# %% [markdown]
# **<추천 시스템>**
# - 사용자의 취향 이해
# - 맞춤 상품과 콘텐츠 제공
# - 잊고 지내왔거나 새로운 취향의 콘텐츠도 소개
# - 사용자 자신도 좋아하는지 몰랐던 취향을 시스템이 발견 -> 콘텐츠 추천
#
# => 고객이 오래 자기 사이트에 머무를 수 있도록 함

# %% [markdown]
# ### **온라인 스토어의 필수 요소, 추천 시스템**

# %% [markdown]
# 대부분의 전자상거래 업체는 너무 많은 상품으로 가득 차 있고, 다양한 상품 이미지와 번잡한 카테고리 등으로 제품 선택의 어려움이 있다. 이는 온라인 쇼핑에 대한 부정적인 이미지가 강해져 결국 매출 감소로 이어질 수 있다.
#
# 추천 시스템은 이런 상황을 해결해준다. 온라인 스토어는 많은 양의 고객과 상품 데이터를 갖고 있다.
# - 사용자가 어떤 상품 구매?
# - 사용자가 어떤 상품을 둘러보거나 장바구니에 넣었나?
# - 사용자가 평가한 영화 평점은?
# - 사용자가 무엇을 클릭?
#
# => 이 데이터 기반으로 사용자가 상품을 구매하도록 유도

# %% [markdown]
# ### **추천 시스템의 유형**

# %% [markdown]
# - 콘텐츠 기반 필터링(Content based filtering)
# - 협업 필터링(Collaborative Filtering)
#   - 최근접 이웃 협업 필터링(Nearest Neighbor)
#   - 잠재 요인 협업 필터링(Latent Factor)
#
# 추천 시스템 초창기에는 콘텐츠 기반 필터링이나 최근접 이웃 기반 협업 필터링 사용. 현재 대부분의 온라인 스토어에서 잠재 요인 협업 필터링 기반의 추천 시스템 적용. 요즘은 개인화 특성을 좀 더 강화하기 위해 하이브리드 형식으로 콘텐츠 기반과 협업 기반을 적절히 결합해 사용.

# %% [markdown]
# ## 2. **콘텐츠 기반 필터링 추천 시스템**

# %% [markdown]
# <콘텐츠 기반 필터링 방식>
#
# : 사용자가 특정한 아이템을 매우 선호하는 경우, 그 아이템과 비슷한 콘텐츠를 가진 다른 아이템 추천하는 방식.
#
# 예를 들어 사용자가 특정 영화에 높은 평점을 줬다면 그 영화의 장르, 출연 배우, 감독, 영화 키워드 등의 콘텐츠와 유사한 다른 영화를 추천해주는 방식이다.

# %% [markdown]
# ## 3. **최근접 이웃 협업 필터링**

# %% [markdown]
# <협업 필터링(Collaborative Filtering)>
#
# : 사용자가 아이템에 매긴 평점 정보나 상품 구매 이력과 같은 사용자 행동 양식(User Behavior)만을 기반으로 추천을 수행하는 것
#
# - 목표: 사용자-아이템 평점 매트릭스 와 같은 축적된 사용자 행동 데이터를 기반으로 사용자가 아직 평가하지 않은 아이템을 예측 평가하는 것
#
# <두 가지 방식>
# 1. 최근접 이웃 방식
# 2. 잠재 요인 방식
#
# <사용자-아이템 평점 행렬 데이터>
# - 두 방식 모두 이 데이터에만 의지
# - 행: 개별 사용자, 열: 개별 아이템
# - 사용자가 아이템에 대한 평점을 매기는 경우가 많지 않기 때문에 희소 행렬 특성

# %% [markdown]
# ![스크린샷 2025-10-12 오전 1.24.12.png](data:image/png;base64,...)

# %% [markdown]
# <최근접 이웃 협업 필터링(메모리 협업 필터링)>
# - 사용자 기반: 사용자와 비슷한 고객들이 구매한 상품
#   - 특정 사용자와 유사한 다른 사용자를 Top-N으로 선정해 그 사용자들이 좋아하는 아이템을 추천하는 방식
#
# - 아이템 기반: 이 상품을 선택한 다른 고객들이 구매한 상품
#   - 사용자들이 그 아이템을 좋아하는 지 싫어하는 지의 평가 척도가 유사한 아이템을 추천하는 기준이 되는 알고리즘

# %% [markdown]
# ## 4. **잠재 요인 협업 필터링**

# %% [markdown]
# ### **잠재 요인 협업 필터링의 이해**
#
# - 사용자-아이템 평점 매트릭스 속에 숨어 있는 잠재 요인을 추출해 추천 예측을 할 수 있게 하는 기법
# - 대규모 다차원 행렬을 SVD와 같은 차원 감소 기법으로 분해하는 과정에서 잠재 요인 추출, 이를 행렬 분해라고 함
#
#
# 잠재 요인을 기반으로 다차원 희소 행렬인 사용자-아이템 행렬 데이터 => 저차원 밀집 행렬의 사용자-잠재 요인 행렬 & 아이템-잠재 요인 행렬의 전치 행렬로 분해
#
# -> 두 행렬의 내적을 통해 새로운 예측 사용자-아이템 평점 행렬 데이터를 만들어서 사용자가 아직 평점을 부여하지 않는 아이템에 대한 예측 평점을 생성

# %% [markdown]
# ![스크린샷 2025-10-12 오전 1.37.30.png](data:image/png;base64,...)

# %% [markdown]
# '잠재 요인'이 정확히 어떤 것인지 알 수 없지만, 영화 평점에서는 영화가 가지는 장르별 특성 선호도로 가정할 수 있다. 즉, 사용자-잠재 요인 행렬은 사용자의 영화 장르에 대한 선호도로, 아이템-잠재 요인 행렬은 영화의 장르별 특성값으로 정의할 수 있다.

# %% [markdown]
# ### **행렬 분해의 이해**
#
# - 행렬 분해: 다차원의 매트릭스를 저차원 매트릭스로 분해하는 기법
#   - SVD(Singular Vector Decoposition), NMF(Non-Negative Matrix Factorization) 등
#   - 분해(인수분해): 하나의 복잡한 다항식을 두 개 이상의 좀 더 단순한 인수의 곱으로 분해하는 것
# - 평점 행렬 R(MXN 차원)
#   - M개의 사용자 행과 N개의 아이템 열
#   - 행렬 분해 -> 사용자-K 차원 잠재 요인 행렬 P / K 차원 잠재요인-아이템 행렬 Q.T

# %% [markdown]
# ![스크린샷 2025-10-12 오후 1.24.10.png](data:image/png;base64,...)

# %% [markdown]
# R = P * Q.T
# - M: 총 사용자 수
# - N: 총 아이템 수
# - K: 잠재 요인의 차원의 수
# - R: MXN 차원의 사용자-아이템 평점 행렬
# - P: 사용자와 잠재 요인과의 관계 값을 갖는 MXK 차원의 사용자-잠재 요인 행렬
# - Q: 아이템과 잠재 요인과의 관계 값을 갖는 NXK 차원의 아이템-잠재 요인 행렬
# - Q.T: Q 매트릭스의 행과 열 값을 교환한 전치 행렬
#
# R행렬을 P와 Q 행렬로 분해하는 방식은 SVD(Singular Value Decomposition). 하지만 SVD는 NaN값이 없는 행렬에만 적용할 수 있음. R 행렬에는 아직 평점이 되지 않은 많은 널 값이 있기에 SVD방식으로 분해할 수 없음. 이런 경우는 확률적 경사 하강법(Stochastic Gradient Descent, SGD)이나 ALS(Alternating Least Squares)방식을 이용.

# %% [markdown]
# ### **확률적 경사 하강법을 이용한 행렬 분해**
#
# - P와 Q 행렬로 계산된 예측 R 행렬 값이 실제 R 행렬 값과 가장 최소의 오류를 가질 수 있도록 반복적인 비용 함수 최적화를 통해 P와 Q를 유추해내는 것
#
# 1. P와 Q를 임의의 값을 가진 행렬로 설정
# 2. P와 Q.T 값을 곱해 예측 R 행렬을 계산하고 예측 R 행렬과 실제 R 행렬에 해당하는 오류 값을 계산
# 3. 이 오류 값을 최소화할 수 있도록 P와 Q 행렬을 적절한 값으로 각각 업데이트
# 4. 2,3번 작업 반복하면서 P와 Q 값을 업데이트해 근사화

# %%
import numpy as np

# 원본 행렬 R 생성, 분해 행렬 P와 Q 초기화, 잠재 요인 차원 K는 3으로 설정
R = np.array([[4, np.nan, np.nan, 2, np.nan],
              [np.nan, 5, np.nan ,3, 1],
              [np.nan, np.nan, 3, 4, 4],
              [5, 2, 1, 2, np.nan]])

num_users, num_items = R.shape
K = 3

# P와 Q 행렬의 크기를 지정하고 정규 분포를 가진 임의의 값으로 입력
np.random.seed(1)
P = np.random.normal(scale=1./K, size=(num_users, K))
Q = np.random.normal(scale=1./K, size=(num_items, K))

# %%
from sklearn.metrics import mean_squared_error

def get_rmse(R, P, Q, non_zeros):
  error = 0

  # 두 개의 분해된 행렬 P와 Q.T의 내적으로 예측 R 행렬 생성
  full_pred_matrix = np.dot(P, Q.T)

  # 실제 R 행렬에서 널이 아닌 값의 위치 인덱스 추출해 실제 R 행렬과 예측 행렬의 RMSE 추출
  x_non_zero_ind = [non_zero[0] for non_zero in non_zeros]
  y_non_zero_ind = [non_zero[1] for non_zero in non_zeros]
  R_non_zeros = R[x_non_zero_ind, y_non_zero_ind]
  full_pred_matrix_non_zeros = full_pred_matrix[x_non_zero_ind, y_non_zero_ind]
  mse = mean_squared_error(R_non_zeros, full_pred_matrix_non_zeros)
  rmse = np.sqrt(mse)

  return rmse

# %%
# R>0인 행 위치, 열 위치, 값을 non_zeros 리스트에 저장
non_zeros = [(i, j, R[i,j]) for i in range(num_users) for j in range(num_items) if R[i,j]>0]

steps = 1000
learning_rate = 0.01
r_lambda = 0.01

# SGD기법으로 P와 Q 매트릭스를 계속 업데이트
for step in range(steps):
  for i, j, r in non_zeros:
    # 실제 값과 예측 값의 차이인 오류 값 구함
    eij = r - np.dot(P[i,:], Q[j,:].T)
    # Regularization을 반영한 SGD 업데이트 공식 적용
    P[i,:] = P[i,:] + learning_rate * (eij * Q[j,:]-r_lambda*P[i,:])
    Q[j,:] = Q[j,:] + learning_rate * (eij * P[i,:]-r_lambda*Q[j,:])

    rmse = get_rmse(R, P, Q, non_zeros)
    if (step % 50) == 0:
      print('### iteration step:', step, "rmse:", rmse)
# Out:
# ### iteration step: 0 rmse: 3.261355059488935
# ### iteration step: 0 rmse: 3.26040057174686
# ### iteration step: 0 rmse: 3.253984404542389
# ### iteration step: 0 rmse: 3.2521583839863624
# ### iteration step: 0 rmse: 3.252335303789125
# ### iteration step: 0 rmse: 3.251072196430487
# ### iteration step: 0 rmse: 3.2492449982564864
# ### iteration step: 0 rmse: 3.247416477570409
# ### iteration step: 0 rmse: 3.241926055455223
# ### iteration step: 0 rmse: 3.2400454107613084
# ### iteration step: 0 rmse: 3.240166740749792
# ### iteration step: 0 rmse: 3.2388050277987723
# ### iteration step: 50 rmse: 0.5003190892212748
# ### iteration step: 50 rmse: 0.5001616291326989
# ### iteration step: 50 rmse: 0.49899601202578087
# ### iteration step: 50 rmse: 0.4988483450145831
# ### iteration step: 50 rmse: 0.49895189256631756
# ### iteration step: 50 rmse: 0.49833236830090993
# ### iteration step: 50 rmse: 0.4984148489378701
# ### iteration step: 50 rmse: 0.49792599580240876
# ...

# %%
pred_matrix = np.dot(P, Q.T)
print('예측 행렬:\n', np.round(pred_matrix, 3))
# Out:
# 예측 행렬:
#  [[3.991 0.897 1.306 2.002 1.663]
#  [6.696 4.978 0.979 2.981 1.003]
#  [6.677 0.391 2.987 3.977 3.986]
#  [4.968 2.005 1.006 2.017 1.14 ]]
